# %%
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import PyPDF2
import numpy as np
import os
from PIL import Image

# %%
filepath = 'C:/git/emileDesmaili.github.io/files/CV.pdf'
# creating a pdf file object
pdfFileObj = open(filepath, 'rb')
  
# creating a pdf reader object
reader = PyPDF2.PdfReader(pdfFileObj)
  
# printing number of pages in pdf file
print(len(reader.pages))
  
# creating a page object
pageObj = reader.pages[0]
  
# extracting text from page
text = pageObj.extract_text()
  
# closing the pdf file object
pdfFileObj.close()

text
# Out:
# 2
# '´Emile Esmaili\n+1 415 740 9561 |ede2110@columbia.edu |LinkedIn |/gtbGitHub |/g♀beWebsite |New York, NY\nEducation\nColumbia University New York, NY\nM.A. in Applied Statistics & Data Science (QMSS)\nSorbonne Universit´ e (Pierre et Marie Curie - Paris VI) Paris, France\nBSc. in Mathematics\nPSL Research University (Paris-Dauphine) Paris, France\nMSc. in Financial Engineering - BSc. in Economics\nResearch Experience\nColumbia University & NASA Goddard Institute for Space Studies New York, NY\nResearch Staff Jan 2024 - June 2025\n•Research staff at the Center for Climate Systems Research supervised by Prof. Michael Puma. and Dr. Andrew\nRobertson\n•Topic 1: Modeling the impact of climate and conflict on food security in early modern Europe using Bayesian\nmultilevel models, econometric contagion models and machine learning\n•Topic 2: Bias correction of subseasonal-to-seasonal (S2S) rainfall forecasts and drought prediction with deep\nlearning\nColumbia University & NASA Goddard Institute for Space Studies New York, NY\nResearch Intern Sep 2022 - Dec 2023\n•Graduate research assistant at NASA GISS and Columbia University’s Department of Earth and Environmental\nEngineering, jointly supervised by Prof. Upmanu Lall and Dr. Michael Puma.\n•Topic: Using hierarchical Bayesian models and Hidden Markov Models to explore the driving factors of global\nmigration and develop improved probabilistic projections of bilateral migration flows\nMemorial Sloan Kettering Cancer Center & Columbia University New York, NY\nPracticum Data Scientist (Capstone Project) Jan 2023 –May 2023\n•Researched drivers of lower grade brain glioma using machine learning and survival models\n•Worked on an image segmentation model for IHC staining based on MSK’s proprietary DeepLIIF model\nConference Papers\n•Modeling Human Migration with Non-Homogeneous Hidden Markov Models: an Application to\nInter-state Mobility in the United States , Emile Esmaili, Upmanu Lall, Michael J.Puma, Aric Cutuli, Rachata\nMuneepeerakul. AGU Fall Meeting 2023\n•A Bayesian Hierarchical Framework for Capturing Preference Heterogeneity in Migration Flows , Aric\nCutuli, Upmanu Lall, Michael J. Puma, Emile Esmaili, Rachata Muneepeerakul. AGU Fall Meeting 2023\nWorking Papers\n•Violent Warfare Ignited Price Contagion Dynamics in Early Modern Europe, Emile Esmaili , Michael\nPuma, Francis Ludlow, Eva Jobbova\n•Compounding Effects of Harsh Climate and Societal Disruptions on Food Prices in Early Modern\nEurope , Emile Esmaili, Michael Puma, Francis Ludlow, Eva Jobbova\nTeaching Experience\nColumbia University New York, NY\nTeaching Assistant - Machine Learning for the Social Sciences (GR5073) Sep 2023 –Dec 2023\n•Held weekly recitations and office hours covering the basics of machine learning and graded homeworks\nColumbia University New York, NY\nTeaching Assistant - Projects in Advanced Machine Learning (GR5074) Jan 2023 –May 2023\n•Held weekly recitations and office hours covering the basics of applied deep learning and graded homeworks'

# %%
mask = np.array(Image.open("images/mask.png"))
font_path = 'assets/fonts/windfonts/impact.ttf'
stopwords = STOPWORDS 
#add custom list of stopwords
stopwords.update(['Puma','Michael','New','York','City','NYC','NY','USA','United','States','America','US','American','Upmanu','Lall',
                  'Jan'])

# Generate the wordcloud
wordcloud = WordCloud(background_color="white", stopwords=STOPWORDS, font_path=font_path,
                       max_words=500, mask=mask,
                         contour_width=0, contour_color='steelblue', colormap='Blues').generate(text)

# Display the wordcloud image
plt.figure(figsize=(6,8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud.to_file('images/wordcloud.png')
