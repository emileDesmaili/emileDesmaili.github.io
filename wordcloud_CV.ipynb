# %%
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import PyPDF2

# %%
  
filepath = 'C:/git/emileDesmaili.github.io/files/CV.pdf'
# creating a pdf file object
pdfFileObj = open(filepath, 'rb')
  
# creating a pdf reader object
reader = PyPDF2.PdfReader(pdfFileObj)
  
# printing number of pages in pdf file
print(len(reader.pages))
  
# creating a page object
pageObj = reader.pages[0]
  
# extracting text from page
text = pageObj.extract_text()
  
# closing the pdf file object
pdfFileObj.close()

text
# Out:
# 1
# ...

# %%
mask = np.array(Image.open(""))
font_path = 'assets/fonts/plt fonts/DejaVuSans-Bold.ttf'

# Generate the wordcloud
wordcloud = WordCloud(background_color="white", stopwords=STOPWORDS, font_path=None,
                       max_words=200, mask=mask,
                         contour_width=3, contour_color='steelblue', colormap='Set2').generate(text)

# Display the wordcloud image
plt.figure(figsize=(6,8), facecolor=None)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.tight_layout(pad=0)
plt.show()

# %%
wordcloud.to_file('images/wordcloud.png')
